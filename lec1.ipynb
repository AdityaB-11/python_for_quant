# %%
c = 0
for i in range(10000000):
    c = c+i
c
# Out:
# 49999995000000

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
np.arange(-1, 2, 0.5, dtype=float)
# Out:
# array([-1. , -0.5,  0. ,  0.5,  1. ,  1.5])

# %%
 x = np.random.normal(0,1,100)

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /home/aditya11/.local/lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /home/aditya11/.local/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/aditya11/.local/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aditya11/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 11.6 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.4 MB/s eta 0:00:00
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [matplotlib]5 [matplotlib]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x);
plt.xlabel("sample data");
plt.legend(['x1']);

# %%
import pandas as pd

# %%
data = get_pricing('MSFT',start_date='2025-1-1',end_date='2025-3-3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data = get_pricing('MSFT',start_date='2025-1-1',end_date='2025-3-3')
#
# NameError: name 'get_pricing' is not defined

# %%
# !{sys.executable} -m pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yfinance
#   Downloading yfinance-0.2.58-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in /home/aditya11/.local/lib/python3.10/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/aditya11/.local/lib/python3.10/site-packages (from yfinance) (1.26.2)
# Requirement already satisfied: requests>=2.31 in /home/aditya11/.local/lib/python3.10/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/aditya11/.local/lib/python3.10/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /home/aditya11/.local/lib/python3.10/site-packages (from yfinance) (2024.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 11.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/aditya11/.local/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.10.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/aditya11/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: cffi>=1.12.0 in /home/aditya11/.local/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /home/aditya11/.local/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: pycparser in /home/aditya11/.local/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aditya11/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/aditya11/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aditya11/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/aditya11/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aditya11/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Downloading yfinance-0.2.58-py2.py3-none-any.whl (113 kB)
# Downloading curl_cffi-0.10.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 13.0 MB/s eta 0:00:00a 0:00:01
# Downloading frozendict-2.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139051 sha256=7b043e79f5c8a0e74b81137c43ebb91b679df6349c8c9be20902ec7207f43263
#   Stored in directory: /home/aditya11/.cache/pip/wheels/8d/c2/af/d591c26196f80ecdedb79664b51642ff1cf49af64d5cd69999
# Successfully built peewee
# Installing collected packages: peewee, multitasking, frozendict, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [yfinance]3/5 [curl_cffi]
# Successfully installed curl_cffi-0.10.0 frozendict-2.4.6 multitasking-0.0.11 peewee-3.18.1 yfinance-0.2.58
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
import yfinance as yf

# %%
data = yf.download('ZOMATO.NS',start='2025-4-1',end='2025-4-4')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker       ZOMATO.NS   ZOMATO.NS   ZOMATO.NS   ZOMATO.NS ZOMATO.NS
# Date
# 2025-04-01  202.009995  205.000000  198.850006  201.699997  63369467
# 2025-04-02  212.029999  212.600006  202.000000  203.500000  59441448
# 2025-04-03  210.899994  214.000000  208.000000  208.149994  44447473

# %%
print(data.head())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-01-02  417.742371  425.217403  414.019854  424.678475  16896500
# 2025-01-03  422.502838  423.181470  418.700465  420.237361  16662900
# 2025-01-06  426.993835  433.450890  424.628583  427.143529  20573600
# 2025-01-07  421.524780  429.788210  419.957915  428.141518  18139100
# 2025-01-08  423.710419  426.115600  420.696473  422.612614  15054600

# %%
y= data['Volume']
y
# Out:
# Ticker      ZOMATO.NS
# Date
# 2025-04-01   63369467
# 2025-04-02   59441448
# 2025-04-03   44447473

# %%
plt.plot(y.index,y.values)
plt.xlabel("date")
plt.ylabel("volume")
# Out:
# Text(0, 0.5, 'volume')
